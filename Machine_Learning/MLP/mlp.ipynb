# %% [markdown]
# # Multi-Layer Perceptron for Image Classification
#
# Welome to the **first** programming assignment of the Deep Learning course.
#
# In this assignment, a complete set of Jupyter Notebook and python scripts are prepared for examining almost all critical factors in designing a Multi-layer Perceptron model.
#
# You will complete the python scripts which have been provided in the project directory to build a deep network, and apply it to a multi-label classification problem. Additionally you will play around varoius factors which may enhance the performance of a deep neural network model.
#
# **After this assignment you will be able to:**
#
#  - Build and apply a deep neural network to supervised learning using PyTorch framework.
#  - See how factors like **Regularization techniques**, **Activation functions**, **Number of layers and units**, **Weights initialization** and **Data augmentation** affect the result of learning process.
#
# **Before you start:** Please read the Submission section at the bottom of the notebook carefully.
#
# Let's get started!

# %% [markdown]
# # 0. Packages and modules
#
# Let's first import all the packages that you will need during this assignment.

# %%
from dataset import SignDigitDataset
from utils import *
from model import MLP
import torch

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"You are using {device}!")
# Out:
# You are using cuda!

# %% [markdown]
# # 1. Dataset
#
# Sign languages (also known as signed languages) are languages that use manual communication to convey meaning. This can include simultaneously employing hand gestures, movement, orientation of the fingers, arms or body, and facial expressions to convey a speaker's ideas. [Source.](https://en.wikipedia.org/wiki/Sign_language)
#
# The dataset that you'll be using during this assignment is a subset of the sign language digits. It contains six different classes representing the digits from 0 to 5. You can see some of the images below.
#
# <p align="center">
#   <img src="images/samples.png">
# </p>
#
# **Problem Statement:** You are given two dataset `train_signs.h5` and `test_signs.h5` containing:
#
#     -- a training/test set of images labelled as one of the classes in {0, 1, 2, 3, 4, 5}.
#     -- each image is of shape (64, 64, 3) where 3 is for the 3 channels (RGB).
#     -- train a MLP model to classify the test images.
#
# Let's get more familiar with the dataset.

# %% [markdown]
# ---
# ## `dataset.py`:
#
# One of the first steps for designing a deep learning model is to get to know the data as best as possible. The better we know the data (shape, data distribution, etc.), the more proper model can be designed.
#
# For this we must create the dataset which we want to feed the model. As we are using PyTorch for this assignment, you must know how to create **torch data loaders**.
#
# In this question you have to complete some parts of `__getitem__()` in `dataset.py` and the following functions in `utils.py`:
#
# - `get_transformations()`: for data transformation and also needed augmentations.
# - `get_one_hot()`: for converting the labels into a model usable labels.
# - `visualize_samples()`: to plot some of the images to see some samples.
#
#
# **Note:** Before that, please visit the official documentaion of pytorch for creating custom datasets to learn how we create them for pytorch deep learning models.
# https://pytorch.org/tutorials/beginner/data_loading_tutorial.html

# %% [markdown]
# ### `get_transformations()`:
#
# As we mentioned earlier, the shape of the tensor we have now of images is **(n_samples, 64, 64, 3)**. But if we want to feed it to a MLP model, we must consider some transformations:
#
#     -- Flattening them to have the shape of (n_samples, 64*64*3).
#     -- Normalizing each pixel has to have a value between 0 - 1.(Hopefully this will be handled automatically)
#     -- Convert the numpy arrays to tensors. (using transforms.ToTensor())
#
# <p align="center">
#   <img src="images/imvectorkiank.png">
# </p>
#
# These were the minimum transformation which must be applied on the input raw images. Later in this assignment we will add some random transformations (a.k.a augmentations) which could affect the performance of the model.

# %% [markdown]
# ### `get_one_hot()`:
#
# Many time in deep learning you will have a $Y$ ranging from 0 to $C-1$, where $C$ is the number of the classes. If $C$ is for example 4, then you might have the following $y$ vector which you will need to convet like this:
#
# <p align="center">
#   <img src="images/onehot.png">
# </p>
#
# This is called **one hot** encoding, because in the converted representation, exactly one element of each column is "hot" (meaning set to 1).

# %% [markdown]
# ### `visualize_samples()`:
#
# At the end of this part, we want to plot some random samples of the dataset. To do this, you have to complete `visualize_samples()` in `utils.py` using [Matplotlib](https://matplotlib.org) funcionalities.
#
# After completing that function, run the cell below to observe the result.

# %%
train_dataset = SignDigitDataset(root_dir='data/',
                                 h5_name='train_signs.h5',
                                 train=True,
                                 transform=get_transformations(64))

test_dataset = SignDigitDataset(root_dir='data/',
                                h5_name='test_signs.h5',
                                train=False,
                                transform=get_transformations(64))
visualize_samples(train_dataset, n_samples=16, cols=4)

# %% [markdown]
# # 2. Architecture of your model
#
# Now that you are familiar with the dataset, it is time to build a deep neural network to classify sign digit images. All the modification which you have consider in this part, must be applied in `model.py`. It consits the a Pytorch class named as **MLP**. All the torch model classes must inherit `torch.nn.Module`.
#
# For a review on how torch models have to be created, please visit the pytorch official documentaion: https://pytorch.org/tutorials/beginner/introyt/modelsyt_tutorial.html
#
# More precisely, in this part, you will complete `MLP.__init__()` and `MLP.forward()` functions:
#
# - `MLP.__init__()`: In this function, all the parameters will be initialized. such as number of layers and units per layer. Note that the model you are implementing must be capable to have every custom number of layers, neurons and also activation layers.
#
# - `MLP.forward()`: For forward propagation purpose. *(~ 1 line of code)*

# %%
# to test the implemented functions (for Debugging purposes)
batch, C, H, W = 10, 3, 64, 64
zero_tensor = torch.zeros([batch, C, H, W], dtype=torch.float32)
zero_tensor = torch.reshape(zero_tensor, (batch, -1))
input_size = C*H*W
num_classes = 6
units = [input_size, 7, 7, num_classes]

mlp = MLP(units=units, hidden_layer_activation='relu')
print(mlp)
out = mlp(zero_tensor)
assert out.shape == torch.Size([batch, num_classes]), f'Model output size expected to be {torch.Size([batch, num_classes])}'
# Out:
# MLP(
#   (activation): ReLU()
#   (mlp): Sequential(
#     (0): Linear(in_features=12288, out_features=7, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=7, out_features=7, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=7, out_features=6, bias=True)
#     (5): ReLU()
#   )
# )

# %% [markdown]
# # 3. Tarining the model
#
# Its time to train your beautiful model :) All you need is a `train.py` file and you have to follow the steps below in order complete it:
#
# 1. Create train and test data loaders with respect to some hyper-parameters including batch_size.
# 2. Get an instance of your MLP model.
# 3. Define an appropriate loss function (e.g. cross entropy loss)
# 4. Define an optimizers with proper hyperparameters such as (learning_rate, ...).
# 5. Implement the main loop function with n_epochs iterations which the learning and evaluation process occurred there. In this loop, you have to log the training and test set loss and accuracy to see if your model works correctly or not.
#
# 6. Save the model weights for laters usages.

# %% [markdown]
# ## 3.1 Train your first MLP model (30 points)
#
# After defining the model we need to trigger training process by using the code partly prepared in `train.py` after filling required lines run the following cell to start training. In this file some writers are defined which are later used for plotting visualizations in tensorboard framework. Summary information defined as scalars (like loss) are saved by this writers in logs folder near existing files.

# %%
# !python train.py --n_epochs 100 --hidden_layers 25 12 --print_every 10 --learning_rate 1e-2 --run_name First_Run

# %% [markdown]
# **Important note:** In this step, your code must work without any bugs and errors and you are free to play around your code to run different traininig procedures to have a saved proper model.
#
# Also by running the cell below, you can your training curves (e.g. loss and accuracy).

# %%
# see the learning curve
# %load_ext tensorboard 
# %tensorboard --logdir=./runs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-3eb13b9046685257" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-3eb13b9046685257");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# # 4. Experimenting on features of an MLP
#
# In the rest of this notebook, some experiments should be done on different setting like regularization, activation function, number of layers, etc combined with some visualizations.

# %% [markdown]
# ## 4.1 Different initializations (20 points)
#
# First we want to see the effect of two common initializers:
#
#  1. Zero constant
#  2. Uniform distribution
#
# At first we use zero initializer **both for biases and weights**. By doing so, specially for weight initialization, the network will get in trouble with **breaking the symmetry.**

# %%
############## YOUR CODES FOR RUNNING EXPERIMENTS OF QUESTION 1 STARTS HERE ##############
# !python train.py --n_epochs 100 --hidden_layers 25 12 --print_every 10 --learning_rate 1e-2 --init_model yes --init_type zero_constant --run_name zero_init
# !python train.py --n_epochs 100 --hidden_layers 25 12 --print_every 10 --learning_rate 1e-2 --init_model yes --init_type uniform --run_name uniform
############## YOUR CODES FOR RUNNING EXPERIMENTS OF QUESTION 1 ENDS HERE ##############
# Out:
# zero_constant
# Epoch [1/100]:	 Train Loss: 1.7918, Test Loss: 16.1259, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [11/100]:	 Train Loss: 1.7918, Test Loss: 16.1259, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [21/100]:	 Train Loss: 1.7918, Test Loss: 16.1259, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [31/100]:	 Train Loss: 1.7918, Test Loss: 16.1259, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [41/100]:	 Train Loss: 1.7918, Test Loss: 16.1259, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [51/100]:	 Train Loss: 1.7918, Test Loss: 16.1259, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [61/100]:	 Train Loss: 1.7918, Test Loss: 16.1259, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [71/100]:	 Train Loss: 1.7918, Test Loss: 16.1259, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [81/100]:	 Train Loss: 1.7918, Test Loss: 16.1259, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [91/100]:	 Train Loss: 1.7918, Test Loss: 16.1259, Train ACC: 0.1667, Test ACC: 0.1667
# uniform
# Epoch [1/100]:	 Train Loss: 1.8769, Test Loss: 16.8923, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [11/100]:	 Train Loss: 1.8769, Test Loss: 16.8923, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [21/100]:	 Train Loss: 1.8769, Test Loss: 16.8923, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [31/100]:	 Train Loss: 1.8769, Test Loss: 16.8923, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [41/100]:	 Train Loss: 1.8769, Test Loss: 16.8923, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [51/100]:	 Train Loss: 1.8769, Test Loss: 16.8923, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [61/100]:	 Train Loss: 1.8769, Test Loss: 16.8923, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [71/100]:	 Train Loss: 1.8769, Test Loss: 16.8923, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [81/100]:	 Train Loss: 1.8769, Test Loss: 16.8923, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [91/100]:	 Train Loss: 1.8769, Test Loss: 16.8923, Train ACC: 0.1667, Test ACC: 0.1667

# %% [markdown]
# ### Question 1:
#
# Use tensorboard visualizations of learning curves (like loss and accuracy to discuss about the issue raised by using zeros initializer for weights. Does uniform random initializing a good choice as weight initialization method?
#
# --------

# %% [markdown]
# ### Answer: Constant is too low and uniform intialization is too high value for such simple network. Intial weights must be very small. I change hyper-parameters but network dosent train. Intial random weghits looks good.

# %%
# %tensorboard --logdir=./runs
# Out:
# Reusing TensorBoard on port 6006 (pid 11176), started 3:05:01 ago. (Use '!kill 11176' to kill it.)
#       <iframe id="tensorboard-frame-bdd640fb06671ad1" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-bdd640fb06671ad1");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## 4.2 Different activation functions (15 points)
#
# Now, lets try different activation functions and evaluate the existence of activation functions amond hidden layers as a powerful to learn non-linear functions. Hence you have to train you model:
#
# 1. Without any activation layer (except softmax function for last layer).
# 2. With `nn.Sigmoid()` as hidden layer activation functions.
# 3. With `nn.ReLu()` as hidden layer activation functions.

# %%
############## YOUR CODES FOR RUNNING EXPERIMENTS OF QUESTION 2 STARTS HERE ##############
# !python train.py --n_epochs 100 --hidden_layers 25 12 --print_every 10 --learning_rate 1e-2 --activation none --run_name no_activation
# !python train.py --n_epochs 100 --hidden_layers 25 12 --print_every 10 --learning_rate 1e-2 --activation sigmoid --run_name sigmoid_activation
# !python train.py --n_epochs 100 --hidden_layers 25 12 --print_every 10 --learning_rate 1e-2 --activation relu --run_name Relu_activation
############## YOUR CODES FOR RUNNING EXPERIMENTS OF QUESTION 2 ENDS HERE ##############
# Out:
# Epoch [1/100]:	 Train Loss: 1.7951, Test Loss: 16.1561, Train ACC: 0.1546, Test ACC: 0.1750
# Epoch [11/100]:	 Train Loss: 1.6455, Test Loss: 14.8093, Train ACC: 0.3926, Test ACC: 0.3583
# Epoch [21/100]:	 Train Loss: 1.4950, Test Loss: 13.4548, Train ACC: 0.5583, Test ACC: 0.4667
# Epoch [31/100]:	 Train Loss: 1.3986, Test Loss: 12.5876, Train ACC: 0.6491, Test ACC: 0.6167
# Epoch [41/100]:	 Train Loss: 1.3631, Test Loss: 12.2681, Train ACC: 0.6861, Test ACC: 0.6500
# Epoch [51/100]:	 Train Loss: 1.3249, Test Loss: 11.9237, Train ACC: 0.7194, Test ACC: 0.6083
# Epoch [61/100]:	 Train Loss: 1.2859, Test Loss: 11.5729, Train ACC: 0.7593, Test ACC: 0.7667
# Epoch [71/100]:	 Train Loss: 1.3098, Test Loss: 11.7879, Train ACC: 0.7333, Test ACC: 0.7417
# Epoch [81/100]:	 Train Loss: 1.2531, Test Loss: 11.2779, Train ACC: 0.7907, Test ACC: 0.7000
# Epoch [91/100]:	 Train Loss: 1.2394, Test Loss: 11.1547, Train ACC: 0.8065, Test ACC: 0.6667
# Epoch [1/100]:	 Train Loss: 1.7918, Test Loss: 16.1262, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [11/100]:	 Train Loss: 1.7918, Test Loss: 16.1261, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [21/100]:	 Train Loss: 1.7918, Test Loss: 16.1259, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [31/100]:	 Train Loss: 1.7917, Test Loss: 16.1257, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [41/100]:	 Train Loss: 1.7917, Test Loss: 16.1256, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [51/100]:	 Train Loss: 1.7917, Test Loss: 16.1254, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [61/100]:	 Train Loss: 1.7917, Test Loss: 16.1253, Train ACC: 0.1676, Test ACC: 0.1750
# Epoch [71/100]:	 Train Loss: 1.7917, Test Loss: 16.1251, Train ACC: 0.1704, Test ACC: 0.1917
# Epoch [81/100]:	 Train Loss: 1.7917, Test Loss: 16.1249, Train ACC: 0.2222, Test ACC: 0.1917
# Epoch [91/100]:	 Train Loss: 1.7916, Test Loss: 16.1247, Train ACC: 0.2185, Test ACC: 0.2250
# Epoch [1/100]:	 Train Loss: 1.7920, Test Loss: 16.1281, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [11/100]:	 Train Loss: 1.7871, Test Loss: 16.0842, Train ACC: 0.2704, Test ACC: 0.3250
# Epoch [21/100]:	 Train Loss: 1.7045, Test Loss: 15.3402, Train ACC: 0.2954, Test ACC: 0.3000
# Epoch [31/100]:	 Train Loss: 1.6214, Test Loss: 14.5930, Train ACC: 0.4102, Test ACC: 0.4333
# Epoch [41/100]:	 Train Loss: 1.5956, Test Loss: 14.3604, Train ACC: 0.4269, Test ACC: 0.4750
# Epoch [51/100]:	 Train Loss: 1.5643, Test Loss: 14.0791, Train ACC: 0.4509, Test ACC: 0.4583
# Epoch [61/100]:	 Train Loss: 1.5500, Test Loss: 13.9498, Train ACC: 0.4528, Test ACC: 0.4917
# Epoch [71/100]:	 Train Loss: 1.5383, Test Loss: 13.8448, Train ACC: 0.4574, Test ACC: 0.4667
# Epoch [81/100]:	 Train Loss: 1.5315, Test Loss: 13.7832, Train ACC: 0.4481, Test ACC: 0.4917
# Epoch [91/100]:	 Train Loss: 1.5254, Test Loss: 13.7282, Train ACC: 0.4639, Test ACC: 0.4500

# %%
# %tensorboard --logdir=./runs
# Out:
# Reusing TensorBoard on port 6006 (pid 11176), started 3:10:13 ago. (Use '!kill 11176' to kill it.)
#       <iframe id="tensorboard-frame-3eb13b9046685257" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-3eb13b9046685257");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ### Question 2:
#
# Use tensorboard visualizations of learning curves (like loss and accuracy to discuss about the impact of learning procedures with/without different activation functions for hidden layers. Which one do you chosse as a best case?
#
# --------

# %% [markdown]
# ### Answer: It Seems that no activation is good for this network. We can see that Relu is much better than sigmoid function.

# %% [markdown]
# ## 4.3 Differnet architectures (20 points)
#
# Next, we will cast light on the importance of architecture of neural networks (more specifically number of layers and units).
#
# In the first one we have 3 hidden layers with 500, 100, 50 units, respectively. This model imposes high computational cost. On the other hand, the second network has one less hidden layer but same number of units in the rest of layers. Totally it has less complexity in terms of number of parameters compared with the first network.

# %%
num_hidden_list = [[500, 100, 50], [100, 50]]

############## YOUR CODES FOR RUNNING EXPERIMENTS OF QUESTION 3 STARTS HERE ##############
# !python train.py --n_epochs 100 --hidden_layers 500 100 50 --print_every 10 --learning_rate 1e-2 --run_name three_hidden
# !python train.py --n_epochs 100 --hidden_layers 100 50 --print_every 10 --learning_rate 1e-2 --run_name two_hidden

############## YOUR CODES FOR RUNNING EXPERIMENTS OF QUESTION 3 ENDS HERE ##############
# Out:
# Epoch [1/100]:	 Train Loss: 1.7918, Test Loss: 16.1265, Train ACC: 0.1667, Test ACC: 0.1667
# Epoch [11/100]:	 Train Loss: 1.7901, Test Loss: 16.1110, Train ACC: 0.1676, Test ACC: 0.1917
# Epoch [21/100]:	 Train Loss: 1.7845, Test Loss: 16.0608, Train ACC: 0.1889, Test ACC: 0.1667
# Epoch [31/100]:	 Train Loss: 1.7566, Test Loss: 15.8096, Train ACC: 0.2352, Test ACC: 0.1833
# Epoch [41/100]:	 Train Loss: 1.7305, Test Loss: 15.5749, Train ACC: 0.2704, Test ACC: 0.2833
# Epoch [51/100]:	 Train Loss: 1.7031, Test Loss: 15.3281, Train ACC: 0.3130, Test ACC: 0.3583
# Epoch [61/100]:	 Train Loss: 1.6742, Test Loss: 15.0675, Train ACC: 0.3583, Test ACC: 0.3833
# Epoch [71/100]:	 Train Loss: 1.6597, Test Loss: 14.9375, Train ACC: 0.3778, Test ACC: 0.3250
# Epoch [81/100]:	 Train Loss: 1.6496, Test Loss: 14.8464, Train ACC: 0.3870, Test ACC: 0.3833
# Epoch [91/100]:	 Train Loss: 1.6593, Test Loss: 14.9333, Train ACC: 0.3870, Test ACC: 0.3500
# Epoch [1/100]:	 Train Loss: 1.7919, Test Loss: 16.1272, Train ACC: 0.1630, Test ACC: 0.1667
# Epoch [11/100]:	 Train Loss: 1.7726, Test Loss: 15.9535, Train ACC: 0.2213, Test ACC: 0.2417
# Epoch [21/100]:	 Train Loss: 1.6968, Test Loss: 15.2710, Train ACC: 0.3185, Test ACC: 0.3333
# Epoch [31/100]:	 Train Loss: 1.6062, Test Loss: 14.4556, Train ACC: 0.3880, Test ACC: 0.2250
# Epoch [41/100]:	 Train Loss: 1.5662, Test Loss: 14.0956, Train ACC: 0.4176, Test ACC: 0.3833
# Epoch [51/100]:	 Train Loss: 1.5100, Test Loss: 13.5902, Train ACC: 0.5333, Test ACC: 0.5167
# Epoch [61/100]:	 Train Loss: 1.4823, Test Loss: 13.3410, Train ACC: 0.5574, Test ACC: 0.5417
# Epoch [71/100]:	 Train Loss: 1.4646, Test Loss: 13.1810, Train ACC: 0.5713, Test ACC: 0.3917
# Epoch [81/100]:	 Train Loss: 1.4528, Test Loss: 13.0753, Train ACC: 0.5852, Test ACC: 0.6000
# Epoch [91/100]:	 Train Loss: 1.4289, Test Loss: 12.8597, Train ACC: 0.6028, Test ACC: 0.5583

# %%
# %tensorboard --logdir=./runs
# Out:
# Reusing TensorBoard on port 6006 (pid 11176), started 3:12:43 ago. (Use '!kill 11176' to kill it.)
#       <iframe id="tensorboard-frame-23b8c1e9392456de" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-23b8c1e9392456de");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ### Question 3:
#
# By using tensorboard visualiztions justify the different outcomes of training the above two neural network architectures.
#
# --------

# %% [markdown]
# ### Answer: As we see in plots, 2 layers network is better than three layers. It is maybe because of big networks has more weights to be learned and network needs more data.

# %% [markdown]
# ## 4.4 Overfitting prevention (15 points)
#
# Another important point to consider is applying regularization or data augmentation methods and being aware of its impact on training and generalization. Its most important rule is to prevent our learning process from overfitting (you may have encountered this phenomenon above!)
#
# In this part you have to modify your codes to support **at least one of the following methods**:
#
# 1. Add some other useful transformation(augmentation) techniques using `torchvision.transforms`. All the codes for this part must be added in `dataset.py` and `utils.py`. (https://pytorch.org/vision/stable/transforms.html)
#
# 2. Add dropout to your hidden layers. Try dropout rates such as 0.2 and 0.5. (https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html)

# %%
############## YOUR CODES FOR RUNNING EXPERIMENTS OF QUESTION 4 STARTS HERE ##############
# !python train.py --n_epochs 100 --hidden_layers 100 50 --print_every 10 --learning_rate 1e-2 --dropout 0.2 --run_name two_hidden_dropout0_2

############## YOUR CODES FOR RUNNING EXPERIMENTS OF QUESTION 4 ENDS HERE ##############
# Out:
# Epoch [1/100]:	 Train Loss: 1.7918, Test Loss: 16.1259, Train ACC: 0.1750, Test ACC: 0.1750
# Epoch [11/100]:	 Train Loss: 1.7740, Test Loss: 15.9660, Train ACC: 0.2389, Test ACC: 0.1750
# Epoch [21/100]:	 Train Loss: 1.7257, Test Loss: 15.5317, Train ACC: 0.2935, Test ACC: 0.3333
# Epoch [31/100]:	 Train Loss: 1.6438, Test Loss: 14.7941, Train ACC: 0.3972, Test ACC: 0.5250
# Epoch [41/100]:	 Train Loss: 1.5943, Test Loss: 14.3488, Train ACC: 0.4389, Test ACC: 0.5167
# Epoch [51/100]:	 Train Loss: 1.5752, Test Loss: 14.1764, Train ACC: 0.4546, Test ACC: 0.5667
# Epoch [61/100]:	 Train Loss: 1.5566, Test Loss: 14.0096, Train ACC: 0.4741, Test ACC: 0.5917
# Epoch [71/100]:	 Train Loss: 1.5292, Test Loss: 13.7624, Train ACC: 0.5056, Test ACC: 0.4917
# Epoch [81/100]:	 Train Loss: 1.4989, Test Loss: 13.4901, Train ACC: 0.5296, Test ACC: 0.6167
# Epoch [91/100]:	 Train Loss: 1.4938, Test Loss: 13.4442, Train ACC: 0.5370, Test ACC: 0.6500

# %%
# !python train.py --n_epochs 100 --hidden_layers 100 50 --print_every 10 --learning_rate 1e-2 --dropout 0.5 --run_name two_hidden_dropout0_5
# Out:
# Epoch [1/100]:	 Train Loss: 1.7930, Test Loss: 16.1371, Train ACC: 0.1741, Test ACC: 0.1667
# Epoch [11/100]:	 Train Loss: 1.7920, Test Loss: 16.1282, Train ACC: 0.1676, Test ACC: 0.1667
# Epoch [21/100]:	 Train Loss: 1.7917, Test Loss: 16.1254, Train ACC: 0.1787, Test ACC: 0.1667
# Epoch [31/100]:	 Train Loss: 1.7927, Test Loss: 16.1345, Train ACC: 0.1435, Test ACC: 0.1667
# Epoch [41/100]:	 Train Loss: 1.7917, Test Loss: 16.1253, Train ACC: 0.1704, Test ACC: 0.1667
# Epoch [51/100]:	 Train Loss: 1.7919, Test Loss: 16.1269, Train ACC: 0.1620, Test ACC: 0.1667
# Epoch [61/100]:	 Train Loss: 1.7918, Test Loss: 16.1262, Train ACC: 0.1704, Test ACC: 0.1667
# Epoch [71/100]:	 Train Loss: 1.7915, Test Loss: 16.1235, Train ACC: 0.1769, Test ACC: 0.1667
# Epoch [81/100]:	 Train Loss: 1.7918, Test Loss: 16.1258, Train ACC: 0.1676, Test ACC: 0.1667
# Epoch [91/100]:	 Train Loss: 1.7919, Test Loss: 16.1270, Train ACC: 0.1556, Test ACC: 0.1667

# %%
# !python train.py --n_epochs 100 --hidden_layers 100 50 --print_every 10 --learning_rate 1e-2 --dropout 0.2 --activation none --run_name two_hidden_dropout0_2_no_activation
# Out:
# Epoch [1/100]:	 Train Loss: 1.7933, Test Loss: 16.1397, Train ACC: 0.1824, Test ACC: 0.1667
# Epoch [11/100]:	 Train Loss: 1.6667, Test Loss: 15.0000, Train ACC: 0.3593, Test ACC: 0.4833
# Epoch [21/100]:	 Train Loss: 1.5722, Test Loss: 14.1502, Train ACC: 0.4639, Test ACC: 0.4167
# Epoch [31/100]:	 Train Loss: 1.4996, Test Loss: 13.4968, Train ACC: 0.5343, Test ACC: 0.5333
# Epoch [41/100]:	 Train Loss: 1.4932, Test Loss: 13.4392, Train ACC: 0.5389, Test ACC: 0.6500
# Epoch [51/100]:	 Train Loss: 1.4667, Test Loss: 13.2007, Train ACC: 0.5713, Test ACC: 0.5333
# Epoch [61/100]:	 Train Loss: 1.4312, Test Loss: 12.8811, Train ACC: 0.6074, Test ACC: 0.7000
# Epoch [71/100]:	 Train Loss: 1.4130, Test Loss: 12.7173, Train ACC: 0.6259, Test ACC: 0.7250
# Epoch [81/100]:	 Train Loss: 1.4161, Test Loss: 12.7447, Train ACC: 0.6222, Test ACC: 0.7333
# Epoch [91/100]:	 Train Loss: 1.4172, Test Loss: 12.7550, Train ACC: 0.6148, Test ACC: 0.6750

# %% [markdown]
# ### Question 4:
#
# By using tensorboard visualiztions justify the different outcomes of training the above two neural network architectures.
# To show this, your learning cuvres must include both training and test curves.
#
# --------

# %% [markdown]
# ### Answer: in CUSTOM_SCALAR tab we can see three runs. first with relu activation and 0.2 dropout, second with 0.5 dropout and relu. between these two plots run with dropout 0.2 is much better and this means that dropout with probability 0.5 will deactivate more nureons and this results no training. I choose 0.2 and based on perevious runs I know that no activation is good choice. Then with no activation and probability 0.2 for dropout I train network and it is better than recent two plots.

# %%
# %tensorboard --logdir=./runs
# Out:
# Reusing TensorBoard on port 6006 (pid 11540), started 0:02:49 ago. (Use '!kill 11540' to kill it.)
#       <iframe id="tensorboard-frame-1a3d1fa7bc8960a9" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-1a3d1fa7bc8960a9");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## 4.5 Hyper-parameters tuning (Optional - 10 points)
#
# Great! We saw how different factors would affect the performance of a MLP model. Now its time to find the best model by tuning various hyper-parameters we have. In this part you are welcomed to train the best model. More specifically, you have to:
#
# 1. Try different hyper-parameters (n_hidden_layers, batch_size, learning_rate, optimizer, momentum rate and etc. )
#
# 2. save the best model as `best_model.pth` and
# 3. Write all the assumed hyper-parameters in `params.yaml` file.
# 4. Use tenorboard to plot the learning curve and report the final loss and accuracy that you get for both training and test sets.

# %%
############## YOUR CODES FOR RUNNING EXPERIMENTS OF QUESTION 5 STARTS HERE ##############

############## YOUR CODES FOR RUNNING EXPERIMENTS OF QUESTION 5 ENDS HERE ##############

# %% [markdown]
# # 5. Submission
#
# Please read the notes here carefully:
#
# 1. In addition to completing the code files, please send a report including your answer to these questions as well. Do not forget to put the diagrams and visualizations needed in each part.
#
# 2. The file you upload must be named as `[Student ID]-[Your name].zip`.
#
# 3. Your notebook must be executed without any problem. If not, you will lose points for each part consequently.
#
# 4. **Important Note:** The outputs of the code blocks must be remained in your notebook, otherwise, you definitly lose all the points of that part.
#
#
# In case you have any questions, contact **mohammad99hashemi@gmail.com** or **naghmefarzi@gmail.com**.
#
# Good luck :)
